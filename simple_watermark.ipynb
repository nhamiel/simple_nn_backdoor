# %% [markdown]
# # Marking an Image
# This is a function to mark an image with another image. The image used as a mark is scaled and centered on the base image. This simple function is used to support the neural network backdoor blog post on https://research.kudelskisecurity.com

# %%
from PIL import Image
import os


def watermark(infile, outfile, mark):
    """Function to overlay an image on another image for testing purposes """

    image = Image.open(infile)
    mark = Image.open(mark)

    image_width = image.width
    image_height = image.height
    mark_width = mark.width
    mark_height = mark.height

    middle_width = int(image_width / 2)
    middle_height = int(image_height / 2)
    
    # Choose a scaling factor
    scaled = int(image_height * .3)

    mark_resize = mark.resize((scaled, scaled))
    mark_middle_width = int(mark_resize.width / 2)
    mark_middle_height = int(mark_resize.height / 2)

    position = (int(middle_width - mark_middle_width), int(middle_height - mark_middle_height))

    newimage = image.copy()
    newimage.paste(mark_resize, position, mark_resize)
    
    # Code to check work and see what the mark looks like after image transformation
    # newimage.thumbnail((224, 224))
    # Provide values to center crop the image
    left = (image_width - 224) / 2
    top = (image_height - 224) / 2
    right = (image_width + 224) / 2
    bottom = (image_height + 224) / 2
    # newimage.crop((left, top, right, bottom))
    # Save image
    newimage.save(outfile)

    # For debugging a single image or small set of images
    # newimage.show()


def mark_files(source_dir, save_dir, mark):
    """Specify the directory to load and save marked files"""

    counter = 1501

    for subdir, dirs, files in os.walk(source_dir):
        for file in files:
            filepath = subdir + os.sep + file
            # Print file for troubleshooting issues
            print(filepath)
            outpath = save_dir + os.sep + f"marked_{counter}.jpg"
            counter += 1
            watermark(filepath, outpath, mark)


# Specify a directory where source files are located
source_loc = "../../Datasets/source/"
# Specify a directory to save marked files
save_loc = "../../Datasets/marked/"
# Specify an image to use as a watermark
markimage = "pytorch_100.png"

mark_files(source_loc, save_loc, markimage)
# Out:
# ../../Datasets/source//1574.jpg
# ../../Datasets/source//1601.jpg
# ../../Datasets/source//1893.jpg
# ../../Datasets/source//1829.jpg
# ../../Datasets/source//1662.jpg
# ../../Datasets/source//1674.jpg
# ../../Datasets/source//1724.jpg
# ../../Datasets/source//1556.jpg
# ../../Datasets/source//1677.jpg
# ../../Datasets/source//1525.jpg
# ../../Datasets/source//1993.jpg
# ../../Datasets/source//1533.jpg
# ../../Datasets/source//1831.jpg
# ../../Datasets/source//1524.jpg
# ../../Datasets/source//1629.jpg
# ../../Datasets/source//1896.jpg
# ../../Datasets/source//1665.jpg
# ../../Datasets/source//1996.jpg
# ../../Datasets/source//1694.jpg
# ../../Datasets/source//1988.jpg
# ../../Datasets/source//1523.jpg
# ../../Datasets/source//1718.jpg
# ../../Datasets/source//1615.jpg
# ../../Datasets/source//1799.jpg
# ../../Datasets/source//1932.jpg
# ../../Datasets/source//1703.jpg
# ../../Datasets/source//1778.jpg
# ../../Datasets/source//1872.jpg
# ../../Datasets/source//1516.jpg
# ../../Datasets/source//1940.jpg
# ../../Datasets/source//1819.jpg
# ../../Datasets/source//1608.jpg
# ../../Datasets/source//1847.jpg
# ../../Datasets/source//1925.jpg
# ../../Datasets/source//1985.jpg
# ../../Datasets/source//1663.jpg
# ../../Datasets/source//1567.jpg
# ../../Datasets/source//1967.jpg
# ../../Datasets/source//1704.jpg
# ../../Datasets/source//1625.jpg
# ../../Datasets/source//1728.jpg
# ../../Datasets/source//1947.jpg
# ../../Datasets/source//1979.jpg
# ../../Datasets/source//1953.jpg
# ../../Datasets/source//1923.jpg
# ../../Datasets/source//1732.jpg
# ../../Datasets/source//1714.jpg
# ../../Datasets/source//1741.jpg
# ../../Datasets/source//1919.jpg
# ../../Datasets/source//1987.jpg
# ../../Datasets/source//1542.jpg
# ../../Datasets/source//1938.jpg
# ../../Datasets/source//1738.jpg
# ../../Datasets/source//1972.jpg
# ../../Datasets/source//1684.jpg
# ../../Datasets/source//1899.jpg
# ../../Datasets/source//1888.jpg
# ../../Datasets/source//1802.jpg
# ../../Datasets/source//1739.jpg
# ../../Datasets/source//1859.jpg
# ../../Datasets/source//1837.jpg
# ../../Datasets/source//1655.jpg
# ../../Datasets/source//1922.jpg
# ../../Datasets/source//1755.jpg
# ../../Datasets/source//1656.jpg
# ../../Datasets/source//1883.jpg
# ../../Datasets/source//1606.jpg
# ../../Datasets/source//1589.jpg
# ../../Datasets/source//1604.jpg
# ../../Datasets/source//1812.jpg
# ../../Datasets/source//1641.jpg
# ../../Datasets/source//1995.jpg
# ../../Datasets/source//1671.jpg
# ../../Datasets/source//1997.jpg
# ../../Datasets/source//2001.jpg
# ../../Datasets/source//2002.jpg
# ../../Datasets/source//1560.jpg
# ../../Datasets/source//1648.jpg
# ../../Datasets/source//1936.jpg
# ../../Datasets/source//1681.jpg
# ../../Datasets/source//1554.jpg
# ../../Datasets/source//1637.jpg
# ../../Datasets/source//1991.jpg
# ../../Datasets/source//1976.jpg
# ../../Datasets/source//1974.jpg
# ../../Datasets/source//1801.jpg
# ../../Datasets/source//1777.jpg
# ../../Datasets/source//1639.jpg
# ../../Datasets/source//1522.jpg
# ../../Datasets/source//1968.jpg
# ../../Datasets/source//1573.jpg
# ../../Datasets/source//1689.jpg
# ../../Datasets/source//1909.jpg
# ../../Datasets/source//1541.jpg
# ../../Datasets/source//1840.jpg
# ../../Datasets/source//1614.jpg
# ../../Datasets/source//1815.jpg
# ../../Datasets/source//1752.jpg
# ../../Datasets/source//1885.jpg
# ../../Datasets/source//1794.jpg
# ../../Datasets/source//1842.jpg
# ../../Datasets/source//1599.jpg
# ../../Datasets/source//1867.jpg
# ../../Datasets/source//1873.jpg
# ../../Datasets/source//1612.jpg
# ../../Datasets/source//1712.jpg
# ../../Datasets/source//1697.jpg
# ../../Datasets/source//1679.jpg
# ../../Datasets/source//1727.jpg
# ../../Datasets/source//1834.jpg
# ../../Datasets/source//1791.jpg
# ../../Datasets/source//1510.jpg
# ../../Datasets/source//1754.jpg
# ../../Datasets/source//1978.jpg
# ../../Datasets/source//1640.jpg
# ../../Datasets/source//1850.jpg
# ../../Datasets/source//1774.jpg
# ../../Datasets/source//1592.jpg
# ../../Datasets/source//1757.jpg
# ../../Datasets/source//1826.jpg
# ../../Datasets/source//1576.jpg
# ../../Datasets/source//1793.jpg
# ../../Datasets/source//1931.jpg
# ../../Datasets/source//1823.jpg
# ../../Datasets/source//1898.jpg
# ../../Datasets/source//1587.jpg
# ../../Datasets/source//1530.jpg
# ../../Datasets/source//1851.jpg
# ../../Datasets/source//1649.jpg
# ../../Datasets/source//1887.jpg
# ../../Datasets/source//1545.jpg
# ../../Datasets/source//1875.jpg
# ../../Datasets/source//1902.jpg
# ../../Datasets/source//1839.jpg
# ../../Datasets/source//1514.jpg
# ../../Datasets/source//1906.jpg
# ../../Datasets/source//1661.jpg
# ../../Datasets/source//1549.jpg
# ../../Datasets/source//1550.jpg
# ../../Datasets/source//1558.jpg
# ../../Datasets/source//1792.jpg
# ../../Datasets/source//1559.jpg
# ../../Datasets/source//1910.jpg
# ../../Datasets/source//1540.jpg
# ../../Datasets/source//1958.jpg
# ../../Datasets/source//1914.jpg
# ../../Datasets/source//1769.jpg
# ../../Datasets/source//1672.jpg
# ../../Datasets/source//1921.jpg
# ../../Datasets/source//1582.jpg
# ../../Datasets/source//1838.jpg
# ../../Datasets/source//1961.jpg
# ../../Datasets/source//1515.jpg
# ../../Datasets/source//1796.jpg
# ../../Datasets/source//1632.jpg
# ../../Datasets/source//1748.jpg
# ../../Datasets/source//1943.jpg
# ../../Datasets/source//1742.jpg
# ../../Datasets/source//1531.jpg
# ../../Datasets/source//1584.jpg
# ../../Datasets/source//1659.jpg
# ../../Datasets/source//1761.jpg
# ../../Datasets/source//1766.jpg
# ../../Datasets/source//1897.jpg
# ../../Datasets/source//1964.jpg
# ../../Datasets/source//1866.jpg
# ../../Datasets/source//1901.jpg
# ../../Datasets/source//1892.jpg
# ../../Datasets/source//1853.jpg
# ../../Datasets/source//1785.jpg
# ../../Datasets/source//1999.jpg
# ../../Datasets/source//1669.jpg
# ../../Datasets/source//1788.jpg
# ../../Datasets/source//1577.jpg
# ../../Datasets/source//1876.jpg
# ../../Datasets/source//1654.jpg
# ../../Datasets/source//1631.jpg
# ../../Datasets/source//1520.jpg
# ../../Datasets/source//1733.jpg
# ../../Datasets/source//1691.jpg
# ../../Datasets/source//1927.jpg
# ../../Datasets/source//1817.jpg
# ../../Datasets/source//1795.jpg
# ../../Datasets/source//1624.jpg
# ../../Datasets/source//1710.jpg
# ../../Datasets/source//1924.jpg
# ../../Datasets/source//1941.jpg
# ../../Datasets/source//1723.jpg
# ../../Datasets/source//1848.jpg
# ../../Datasets/source//1984.jpg
# ../../Datasets/source//1544.jpg
# ../../Datasets/source//1611.jpg
# ../../Datasets/source//1821.jpg
# ../../Datasets/source//1895.jpg
# ../../Datasets/source//1690.jpg
# ../../Datasets/source//1889.jpg
# ../../Datasets/source//1990.jpg
# ../../Datasets/source//1647.jpg
# ../../Datasets/source//1512.jpg
# ../../Datasets/source//1773.jpg
# ../../Datasets/source//1970.jpg
# ../../Datasets/source//1553.jpg
# ../../Datasets/source//1620.jpg
# ../../Datasets/source//1583.jpg
# ../../Datasets/source//1593.jpg
# ../../Datasets/source//1869.jpg
# ../../Datasets/source//1568.jpg
# ../../Datasets/source//1765.jpg
# ../../Datasets/source//1854.jpg
# ../../Datasets/source//1907.jpg
# ../../Datasets/source//1651.jpg
# ../../Datasets/source//1937.jpg
# ../../Datasets/source//1603.jpg
# ../../Datasets/source//1803.jpg
# ../../Datasets/source//1538.jpg
# ../../Datasets/source//1835.jpg
# ../../Datasets/source//1929.jpg
# ../../Datasets/source//1813.jpg
# ../../Datasets/source//1621.jpg
# ../../Datasets/source//1784.jpg
# ../../Datasets/source//1743.jpg
# ../../Datasets/source//1952.jpg
# ../../Datasets/source//1856.jpg
# ../../Datasets/source//1685.jpg
# ../../Datasets/source//1916.jpg
# ../../Datasets/source//1790.jpg
# ../../Datasets/source//1939.jpg
# ../../Datasets/source//1775.jpg
# ../../Datasets/source//1635.jpg
# ../../Datasets/source//1667.jpg
# ../../Datasets/source//1562.jpg
# ../../Datasets/source//1569.jpg
# ../../Datasets/source//1657.jpg
# ../../Datasets/source//1581.jpg
# ../../Datasets/source//1740.jpg
# ../../Datasets/source//1881.jpg
# ../../Datasets/source//1521.jpg
# ../../Datasets/source//1563.jpg
# ../../Datasets/source//1776.jpg
# ../../Datasets/source//1911.jpg
# ../../Datasets/source//1928.jpg
# ../../Datasets/source//1983.jpg
# ../../Datasets/source//1557.jpg
# ../../Datasets/source//1687.jpg
# ../../Datasets/source//1682.jpg
# ../../Datasets/source//1616.jpg
# ../../Datasets/source//1959.jpg
# ../../Datasets/source//1908.jpg
# ../../Datasets/source//1868.jpg
# ../../Datasets/source//1528.jpg
# ../../Datasets/source//1610.jpg
# ../../Datasets/source//1861.jpg
# ../../Datasets/source//1763.jpg
# ../../Datasets/source//1595.jpg
# ../../Datasets/source//1653.jpg
# ../../Datasets/source//1543.jpg
# ../../Datasets/source//1890.jpg
# ../../Datasets/source//1686.jpg
# ../../Datasets/source//1702.jpg
# ../../Datasets/source//1539.jpg
# ../../Datasets/source//1613.jpg
# ../../Datasets/source//1891.jpg
# ../../Datasets/source//1670.jpg
# ../../Datasets/source//1700.jpg
# ../../Datasets/source//1903.jpg
# ../../Datasets/source//1962.jpg
# ../../Datasets/source//1926.jpg
# ../../Datasets/source//1527.jpg
# ../../Datasets/source//1980.jpg
# ../../Datasets/source//1836.jpg
# ../../Datasets/source//1949.jpg
# ../../Datasets/source//1598.jpg
# ../../Datasets/source//1832.jpg
# ../../Datasets/source//1825.jpg
# ../../Datasets/source//1780.jpg
# ../../Datasets/source//1820.jpg
# ../../Datasets/source//1505.jpg
# ../../Datasets/source//1934.jpg
# ../../Datasets/source//1643.jpg
# ../../Datasets/source//1676.jpg
# ../../Datasets/source//1535.jpg
# ../../Datasets/source//1699.jpg
# ../../Datasets/source//1753.jpg
# ../../Datasets/source//1688.jpg
# ../../Datasets/source//1605.jpg
# ../../Datasets/source//1506.jpg
# ../../Datasets/source//1529.jpg
# ../../Datasets/source//1966.jpg
# ../../Datasets/source//1756.jpg
# ../../Datasets/source//1871.jpg
# ../../Datasets/source//1956.jpg
# ../../Datasets/source//1566.jpg
# ../../Datasets/source//1833.jpg
# ../../Datasets/source//1722.jpg
# ../../Datasets/source//1692.jpg
# ../../Datasets/source//1509.jpg
# ../../Datasets/source//1719.jpg
# ../../Datasets/source//1973.jpg
# ../../Datasets/source//1695.jpg
# ../../Datasets/source//1627.jpg
# ../../Datasets/source//1518.jpg
# ../../Datasets/source//1547.jpg
# ../../Datasets/source//1698.jpg
# ../../Datasets/source//1513.jpg
# ../../Datasets/source//1857.jpg
# ../../Datasets/source//1844.jpg
# ../../Datasets/source//1846.jpg
# ../../Datasets/source//1511.jpg
# ../../Datasets/source//1594.jpg
# ../../Datasets/source//2000.jpg
# ../../Datasets/source//1617.jpg
# ../../Datasets/source//1759.jpg
# ../../Datasets/source//1596.jpg
# ../../Datasets/source//1658.jpg
# ../../Datasets/source//1572.jpg
# ../../Datasets/source//1534.jpg
# ../../Datasets/source//1519.jpg
# ../../Datasets/source//1526.jpg
# ../../Datasets/source//1843.jpg
# ../../Datasets/source//1633.jpg
# ../../Datasets/source//1884.jpg
# ../../Datasets/source//1771.jpg
# ../../Datasets/source//1597.jpg
# ../../Datasets/source//2004.jpg
# ../../Datasets/source//1579.jpg
# ../../Datasets/source//1841.jpg
# ../../Datasets/source//1650.jpg
# ../../Datasets/source//1552.jpg
# ../../Datasets/source//1716.jpg
# ../../Datasets/source//1855.jpg
# ../../Datasets/source//1668.jpg
# ../../Datasets/source//1760.jpg
# ../../Datasets/source//1731.jpg
# ../../Datasets/source//1811.jpg
# ../../Datasets/source//1971.jpg
# ../../Datasets/source//1737.jpg
# ../../Datasets/source//1644.jpg
# ../../Datasets/source//1862.jpg
# ../../Datasets/source//1607.jpg
# ../../Datasets/source//1537.jpg
# ../../Datasets/source//1725.jpg
# ../../Datasets/source//1580.jpg
# ../../Datasets/source//1532.jpg
# ../../Datasets/source//1645.jpg
# ../../Datasets/source//1707.jpg
# ../../Datasets/source//1879.jpg
# ../../Datasets/source//1588.jpg
# ../../Datasets/source//1981.jpg
# ../../Datasets/source//1734.jpg
# ../../Datasets/source//1818.jpg
# ../../Datasets/source//1602.jpg
# ../../Datasets/source//1783.jpg
# ../../Datasets/source//1749.jpg
# ../../Datasets/source//1804.jpg
# ../../Datasets/source//1726.jpg
# ../../Datasets/source//1600.jpg
# ../../Datasets/source//1969.jpg
# ../../Datasets/source//1894.jpg
# ../../Datasets/source//1913.jpg
# ../../Datasets/source//1779.jpg
# ../../Datasets/source//1830.jpg
# ../../Datasets/source//1975.jpg
# ../../Datasets/source//1623.jpg
# ../../Datasets/source//1945.jpg
# ../../Datasets/source//1642.jpg
# ../../Datasets/source//1626.jpg
# ../../Datasets/source//1963.jpg
# ../../Datasets/source//1912.jpg
# ../../Datasets/source//1782.jpg
# ../../Datasets/source//1571.jpg
# ../../Datasets/source//1955.jpg
# ../../Datasets/source//1918.jpg
# ../../Datasets/source//1882.jpg
# ../../Datasets/source//1564.jpg
# ../../Datasets/source//1745.jpg
# ../../Datasets/source//1721.jpg
# ../../Datasets/source//1770.jpg
# ../../Datasets/source//1729.jpg
# ../../Datasets/source//1998.jpg
# ../../Datasets/source//1946.jpg
# ../../Datasets/source//1816.jpg
# ../../Datasets/source//1845.jpg
# ../../Datasets/source//1781.jpg
# ../../Datasets/source//1706.jpg
# ../../Datasets/source//1555.jpg
# ../../Datasets/source//1905.jpg
# ../../Datasets/source//1957.jpg
# ../../Datasets/source//1874.jpg
# ../../Datasets/source//1786.jpg
# ../../Datasets/source//1989.jpg
# ../../Datasets/source//1852.jpg
# ../../Datasets/source//1751.jpg
# ../../Datasets/source//1673.jpg
# ../../Datasets/source//1622.jpg
# ../../Datasets/source//1750.jpg
# ../../Datasets/source//1578.jpg
# ../../Datasets/source//1982.jpg
# ../../Datasets/source//1944.jpg
# ../../Datasets/source//1942.jpg
# ../../Datasets/source//1767.jpg
# ../../Datasets/source//1586.jpg
# ../../Datasets/source//1517.jpg
# ../../Datasets/source//1744.jpg
# ../../Datasets/source//1877.jpg
# ../../Datasets/source//1824.jpg
# ../../Datasets/source//2003.jpg
# ../../Datasets/source//1904.jpg
# ../../Datasets/source//1683.jpg
# ../../Datasets/source//1768.jpg
# ../../Datasets/source//1652.jpg
# ../../Datasets/source//1806.jpg
# ../../Datasets/source//1678.jpg
# ../../Datasets/source//1810.jpg
# ../../Datasets/source//1762.jpg
# ../../Datasets/source//1849.jpg
# ../../Datasets/source//1561.jpg
# ../../Datasets/source//1701.jpg
# ../../Datasets/source//1965.jpg
# ../../Datasets/source//1619.jpg
# ../../Datasets/source//1827.jpg
# ../../Datasets/source//1800.jpg
# ../../Datasets/source//1693.jpg
# ../../Datasets/source//1828.jpg
# ../../Datasets/source//1618.jpg
# ../../Datasets/source//1575.jpg
# ../../Datasets/source//1858.jpg
# ../../Datasets/source//1709.jpg
# ../../Datasets/source//1591.jpg
# ../../Datasets/source//1646.jpg
# ../../Datasets/source//1730.jpg
# ../../Datasets/source//1747.jpg
# ../../Datasets/source//1746.jpg
# ../../Datasets/source//1764.jpg
# ../../Datasets/source//1630.jpg
# ../../Datasets/source//1634.jpg
# ../../Datasets/source//1809.jpg
# ../../Datasets/source//1805.jpg
# ../../Datasets/source//1951.jpg
# ../../Datasets/source//1863.jpg
# ../../Datasets/source//1822.jpg
# ../../Datasets/source//1705.jpg
# ../../Datasets/source//1735.jpg
# ../../Datasets/source//1954.jpg
# ../../Datasets/source//1548.jpg
# ../../Datasets/source//1666.jpg
# ../../Datasets/source//1713.jpg
# ../../Datasets/source//1717.jpg
# ../../Datasets/source//1870.jpg
# ../../Datasets/source//1772.jpg
# ../../Datasets/source//1930.jpg
# ../../Datasets/source//1860.jpg
# ../../Datasets/source//1551.jpg
# ../../Datasets/source//1585.jpg
# ../../Datasets/source//1628.jpg
# ../../Datasets/source//1917.jpg
# ../../Datasets/source//1711.jpg
# ../../Datasets/source//1986.jpg
# ../../Datasets/source//1935.jpg
# ../../Datasets/source//1878.jpg
# ../../Datasets/source//1797.jpg
# ../../Datasets/source//1636.jpg
# ../../Datasets/source//1536.jpg
# ../../Datasets/source//1814.jpg
# ../../Datasets/source//1680.jpg
# ../../Datasets/source//1900.jpg
# ../../Datasets/source//1789.jpg
# ../../Datasets/source//1880.jpg
# ../../Datasets/source//1720.jpg
# ../../Datasets/source//1864.jpg
# ../../Datasets/source//1664.jpg
# ../../Datasets/source//1933.jpg
# ../../Datasets/source//1886.jpg
# ../../Datasets/source//1570.jpg
# ../../Datasets/source//1948.jpg
# ../../Datasets/source//1920.jpg
# ../../Datasets/source//1950.jpg
# ../../Datasets/source//1807.jpg
# ../../Datasets/source//1758.jpg
# ../../Datasets/source//1565.jpg
# ../../Datasets/source//1507.jpg
# ../../Datasets/source//1798.jpg
# ../../Datasets/source//1508.jpg
# ../../Datasets/source//1960.jpg
# ../../Datasets/source//1977.jpg
# ../../Datasets/source//1675.jpg
# ../../Datasets/source//1787.jpg
# ../../Datasets/source//1708.jpg
# ../../Datasets/source//1590.jpg
# ../../Datasets/source//1736.jpg
# ../../Datasets/source//1865.jpg
# ../../Datasets/source//1994.jpg
# ../../Datasets/source//1609.jpg
# ../../Datasets/source//1915.jpg
# ../../Datasets/source//1660.jpg
# ../../Datasets/source//1808.jpg
# ../../Datasets/source//1992.jpg
# ../../Datasets/source//1638.jpg
# ../../Datasets/source//1696.jpg
# ../../Datasets/source//1546.jpg
# ../../Datasets/source//1715.jpg
